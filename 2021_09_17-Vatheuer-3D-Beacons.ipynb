# %% [markdown]
# # Impressions de vacances

# %% [markdown]
# ![Sundawn.jpg](attachment:Sundawn.jpg)

# %% [markdown]
# # Science: Protein structures
#
# [3D-Beacons](https://www.ebi.ac.uk/pdbe/pdbe-kb/3dbeacons/)
